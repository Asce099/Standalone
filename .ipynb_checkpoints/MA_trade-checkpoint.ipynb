# %%
import os 
from glob import glob
import pandas as pd
import numpy as np
from tqdm import tqdm
from matplotlib import dates as mdates
import datetime as dt
import mplfinance as mpf
import matplotlib.pyplot as plt
from mplfinance.original_flavor import candlestick_ohlc
import talib as ta

# %%
select_tf = ["day", "60minute", 'minute']
tables = [] 
final_data = {}

for filename in tqdm(glob('TI_Data/*')):
    names = (filename.split(os.sep)[-1].split('_'))
    company_name = names[0]
    if names[1] in select_tf:
        data = pd.read_csv(filename, index_col=0)
        tf = names[1]
        variable_name = f"{company_name}_{tf}"
        locals()[variable_name] = data
        tables.append(variable_name)
        final_data[variable_name] = data
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 303/303 [03:50<00:00,  1.32it/s]

# %%
def indexer(dicta):
    for df in dicta.values():
        df.reset_index(inplace=True)
        df.rename(columns={'index': 'Index_Column'}, inplace=True)
    return dicta

# %%
indexer(final_data)
# Out:
# {'ACC_60minute':             datec          date    close     high      low    open  volume  \
#  0      2015-02-02  16468.156250  1545.25  1556.70  1536.05  1554.9   44022
#  1      2015-02-02  16468.197917  1540.30  1548.00  1538.10  1545.2   16177
#  2      2015-02-02  16468.239583  1526.00  1544.30  1523.85  1540.3   30934
#  3      2015-02-02  16468.281250  1535.00  1536.05  1524.15  1527.0   15622
#  4      2015-02-02  16468.322917  1552.00  1552.00  1531.55  1535.0   29767
#  ...           ...           ...      ...      ...      ...     ...     ...
#  12769  2022-10-21  19286.239583  2254.00  2267.95  2254.00  2261.4   41742
#  12770  2022-10-21  19286.281250  2256.40  2261.95  2250.60  2254.5   45546
#  12771  2022-10-21  19286.322917  2246.50  2258.00  2241.05  2256.4   39277
#  12772  2022-10-21  19286.364583  2256.60  2260.00  2244.20  2246.4   60867
#  12773  2022-10-21  19286.406250  2257.00  2261.30  2254.30  2256.6   26828
#
#         VolumePositive  Doji  IsDoji  ...  macdhist  Gain   Loss  AVG_Gain  \
#  0               False     0   False  ...       NaN   NaN    NaN       NaN
#  1               False     0   False  ...       NaN   0.0   4.95       NaN
#  2               False     0   False  ...       NaN   0.0  14.30       NaN
#  3                True     0   False  ...       NaN   9.0   0.00       NaN
#  4                True     0   False  ...       NaN  17.0   0.00       NaN
#  ...               ...   ...     ...  ...       ...   ...    ...       ...
#  12769           False     0   False  ...  2.502559   0.0   7.40  5.971429
#  12770            True   100    True  ...  1.326117   2.4   0.00  5.417857
#  12771           False     0   False  ... -0.132303   0.0   9.90  5.039286
#  12772            True     0   False  ... -0.414354  10.1   0.00  5.760714
#  12773            True   100    True  ... -0.562380   0.4   0.00  5.789286
#
#         AVG_Loss        RS        RSI     RSI_ta       FI_1          FI_13
#  0           NaN       NaN        NaN        NaN        NaN            NaN
#  1           NaN       NaN        NaN        NaN  -80076.15            NaN
#  2           NaN       NaN        NaN        NaN -442356.20            NaN
#  3           NaN       NaN        NaN        NaN  140598.00            NaN
#  4           NaN       NaN        NaN        NaN  506039.00            NaN
#  ...         ...       ...        ...        ...        ...            ...
#  12769  4.764286  1.253373  55.622089  48.327571 -308890.80  195318.040382
#  12770  4.764286  1.137181  53.209400  49.187396  109310.40  183031.234613
#  12771  5.471429  0.921018  47.944275  45.801748 -388842.30  101335.015383
#  12772  4.914286  1.172238  53.964537  49.612263  614756.70  174680.970328
#  12773  4.582143  1.263445  55.819559  49.762905   10731.20  151259.574567
#
#  [12774 rows x 27 columns],
#  'ACC_day':            datec          date    close     high      low     open   volume  \
#  0     2015-01-01  16435.770833  1403.55  1411.00  1397.95  1400.15   101070
#  1     2015-01-02  16436.770833  1425.90  1431.00  1405.55  1406.40   153349
#  2     2015-01-05  16439.770833  1433.65  1439.75  1423.75  1425.00   207979
#  3     2015-01-06  16440.770833  1383.55  1428.95  1370.55  1425.00   368755
#  4     2015-01-07  16441.770833  1367.45  1384.95  1336.20  1382.00   301895
#  ...          ...           ...      ...      ...      ...      ...      ...
#  1902  2022-10-17  19281.770833  2270.10  2285.05  2205.30  2232.00  1512370
#  1903  2022-10-18  19282.770833  2219.25  2293.20  2216.00  2259.00  1189726
#  1904  2022-10-19  19283.770833  2246.45  2258.40  2212.55  2219.00   724058
#  1905  2022-10-20  19284.770833  2287.60  2299.00  2227.95  2230.00   713402
#  1906  2022-10-21  19285.770833  2256.55  2300.00  2241.05  2271.00   389554
#
#        VolumePositive  Doji  IsDoji  ...   macdhist   Gain   Loss   AVG_Gain  \
#  0               True     0   False  ...        NaN    NaN    NaN        NaN
#  1               True     0   False  ...        NaN  22.35   0.00        NaN
#  2               True     0   False  ...        NaN   7.75   0.00        NaN
#  3              False     0   False  ...        NaN   0.00  50.10        NaN
#  4              False     0   False  ...        NaN   0.00  16.10        NaN
#  ...              ...   ...     ...  ...        ...    ...    ...        ...
#  1902            True     0   False  ... -22.593903  26.45   0.00  12.885714
#  1903           False     0   False  ... -22.847446   0.00  50.85  12.885714
#  1904            True     0   False  ... -19.874054  27.20   0.00  14.828571
#  1905            True     0   False  ... -14.098397  41.15   0.00  16.071429
#  1906           False     0   False  ... -11.444607   0.00  31.05  13.100000
#
#         AVG_Loss        RS        RSI     RSI_ta         FI_1         FI_13
#  0           NaN       NaN        NaN        NaN          NaN           NaN
#  1           NaN       NaN        NaN        NaN   3427350.15           NaN
#  2           NaN       NaN        NaN        NaN   1611837.25           NaN
#  3           NaN       NaN        NaN        NaN -18474625.50           NaN
#  4           NaN       NaN        NaN        NaN  -4860509.50           NaN
#  ...         ...       ...        ...        ...          ...           ...
#  1902  20.610714  0.625195  38.468920  41.112831  40002186.50 -5.048376e+06
#  1903  23.900000  0.539151  35.029126  37.675232 -60497567.10 -1.296969e+07
#  1904  22.246429  0.666560  39.996147  40.539219  19694377.60 -8.303394e+06
#  1905  22.246429  0.722427  41.942399  44.680851  29356492.30 -2.923410e+06
#  1906  24.464286  0.535474  34.873550  42.287380 -12095651.70 -4.233730e+06
#
#  [1907 rows x 27 columns],
#  'ACC_minute':              datec          date    close     high      low     open  volume  \
#  0       2015-02-02  16468.156250  1549.60  1556.70  1544.80  1554.90    1441
#  1       2015-02-02  16468.156944  1548.30  1551.30  1546.50  1550.70     424
#  2       2015-02-02  16468.157639  1547.55  1549.00  1545.15  1548.35     831
#  3       2015-02-02  16468.158333  1544.20  1547.55  1543.00  1547.55    1297
#  4       2015-02-02  16468.159028  1547.75  1547.75  1544.25  1544.25     255
#  ...            ...           ...      ...      ...      ...      ...     ...
#  660591  2022-10-24  19289.569444  2255.00  2255.90  2254.55  2255.80     199
#  660592  2022-10-24  19289.570139  2255.95  2255.95  2254.55  2255.75     227
#  660593  2022-10-24  19289.570833  2256.25  2256.25  2255.35  2256.00     594
#  660594  2022-10-24  19289.571528  2255.00  2255.95  2254.55  2255.50     267
#  660595  2022-10-24  19289.572222  2256.00  2259.00  2254.00  2255.00     365
#
#          VolumePositive  Doji  IsDoji  ...  macdhist  Gain  Loss  AVG_Gain  \
#  0                False     0   False  ...       NaN   NaN   NaN       NaN
#  1                False     0   False  ...       NaN  0.00  1.30       NaN
#  2                False     0   False  ...       NaN  0.00  0.75       NaN
#  3                False     0   False  ...       NaN  0.00  3.35       NaN
#  4                 True     0   False  ...       NaN  3.55  0.00       NaN
#  ...                ...   ...     ...  ...       ...   ...   ...       ...
#  660591           False     0   False  ... -0.241048  0.00  0.80  0.464286
#  660592            True   100    True  ... -0.096314  0.95  0.00  0.528571
#  660593            True     0   False  ...  0.029938  0.30  0.00  0.489286
#  660594           False     0   False  ...  0.039001  0.00  1.25  0.489286
#  660595            True     0   False  ...  0.117638  1.00  0.00  0.560714
#
#          AVG_Loss        RS        RSI     RSI_ta     FI_1       FI_13
#  0            NaN       NaN        NaN        NaN      NaN         NaN
#  1            NaN       NaN        NaN        NaN  -551.20         NaN
#  2            NaN       NaN        NaN        NaN  -623.25         NaN
#  3            NaN       NaN        NaN        NaN -4344.95         NaN
#  4            NaN       NaN        NaN        NaN   905.25         NaN
#  ...          ...       ...        ...        ...      ...         ...
#  660591  0.817857  0.567686  36.211699  42.635409  -159.20 -266.470904
#  660592  0.817857  0.646288  39.257294  45.887956   215.65 -197.596489
#  660593  0.817857  0.598253  37.431694  46.911629   178.20 -143.911277
#  660594  0.667857  0.732620  42.283951  43.241031  -333.75 -171.031094
#  660595  0.635714  0.882022  46.865672  46.825574   365.00  -94.455224
#
#  [660596 rows x 27 columns],
#  'ADANIENT_60minute':             datec          date    close     high      low     open   volume  \
#  0      2015-02-02  16468.156250   648.00   662.30   641.90   646.90  2518240
#  1      2015-02-02  16468.197917   644.85   649.00   639.10   648.40   901256
#  2      2015-02-02  16468.239583   643.95   645.60   642.30   644.85   195940
#  3      2015-02-02  16468.281250   650.90   655.00   643.00   643.95   783039
#  4      2015-02-02  16468.322917   646.00   653.50   641.10   650.90   499288
#  ...           ...           ...      ...      ...      ...      ...      ...
#  12769  2022-10-21  19286.239583  3348.00  3361.00  3340.00  3342.05    94469
#  12770  2022-10-21  19286.281250  3331.60  3348.45  3326.75  3347.90    98770
#  12771  2022-10-21  19286.322917  3305.40  3335.75  3287.05  3331.60   208581
#  12772  2022-10-21  19286.364583  3311.80  3318.95  3288.00  3305.40   195780
#  12773  2022-10-21  19286.406250  3309.00  3316.60  3306.25  3311.80    73051
#
#         VolumePositive  Doji  IsDoji  ...  macdhist  Gain   Loss  AVG_Gain  \
#  0                True     0   False  ...       NaN   NaN    NaN       NaN
#  1               False     0   False  ...       NaN  0.00   3.15       NaN
#  2               False     0   False  ...       NaN  0.00   0.90       NaN
#  3                True     0   False  ...       NaN  6.95   0.00       NaN
#  4               False     0   False  ...       NaN  0.00   4.90       NaN
#  ...               ...   ...     ...  ...       ...   ...    ...       ...
#  12769            True     0   False  ...  5.146152  5.95   0.00  7.839286
#  12770           False     0   False  ...  2.897805  0.00  16.40  7.839286
#  12771           False     0   False  ... -0.531742  0.00  26.20  7.839286
#  12772            True     0   False  ... -2.440191  6.40   0.00  8.296429
#  12773           False   100    True  ... -3.876762  0.00   2.80  8.103571
#
#         AVG_Loss        RS        RSI     RSI_ta        FI_1         FI_13
#  0           NaN       NaN        NaN        NaN         NaN           NaN
#  1           NaN       NaN        NaN        NaN -2838956.40           NaN
#  2           NaN       NaN        NaN        NaN  -176346.00           NaN
#  3           NaN       NaN        NaN        NaN  5442121.05           NaN
#  4           NaN       NaN        NaN        NaN -2446511.20           NaN
#  ...         ...       ...        ...        ...         ...           ...
#  12769  4.339286  1.806584  64.369501  65.325288   562090.55  2.064324e+06
#  12770  5.078571  1.543601  60.685651  59.206532 -1619828.00  1.538017e+06
#  12771  6.732143  1.164456  53.799020  50.989668 -5464822.20  5.376114e+05
#  12772  5.617857  1.476796  59.625257  52.715960  1252992.00  6.398086e+05
#  12773  5.817857  1.392879  58.209338  51.855396  -204542.80  5.191870e+05
#
#  [12774 rows x 27 columns],
#  'ADANIENT_day':            datec          date    close     high      low    open   volume  \
#  0     2015-01-01  16435.770833   490.00   492.55   480.60   485.4   604947
#  1     2015-01-02  16436.770833   492.40   497.00   490.00   491.3  1006286
#  2     2015-01-05  16439.770833   500.55   506.55   490.70   491.1  1441527
#  3     2015-01-06  16440.770833   496.75   517.90   484.20   495.6  2822168
#  4     2015-01-07  16441.770833   492.35   507.55   482.00   500.0  1665081
#  ...          ...           ...      ...      ...      ...     ...      ...
#  1902  2022-10-17  19281.770833  3212.60  3235.00  3136.10  3211.0  1985298
#  1903  2022-10-18  19282.770833  3284.30  3298.00  3226.10  3249.0  1635079
#  1904  2022-10-19  19283.770833  3277.25  3310.00  3259.65  3300.0  1396513
#  1905  2022-10-20  19284.770833  3357.10  3365.00  3245.00  3260.0  2211287
#  1906  2022-10-21  19285.770833  3311.90  3382.00  3287.00  3374.9  1120790
#
#        VolumePositive  Doji  IsDoji  ...   macdhist   Gain   Loss   AVG_Gain  \
#  0               True     0   False  ...        NaN    NaN    NaN        NaN
#  1               True     0   False  ...        NaN   2.40   0.00        NaN
#  2               True     0   False  ...        NaN   8.15   0.00        NaN
#  3               True     0   False  ...        NaN   0.00   3.80        NaN
#  4              False     0   False  ...        NaN   0.00   4.40        NaN
#  ...              ...   ...     ...  ...        ...    ...    ...        ...
#  1902            True   100    True  ... -43.152805   3.10   0.00  12.035714
#  1903            True     0   False  ... -32.852289  71.70   0.00  17.157143
#  1904           False     0   False  ... -25.090712   0.00   7.05  17.157143
#  1905            True     0   False  ... -13.724426  79.85   0.00  22.860714
#  1906           False     0   False  ...  -8.643735   0.00  45.20  22.860714
#
#         AVG_Loss        RS        RSI     RSI_ta          FI_1         FI_13
#  0           NaN       NaN        NaN        NaN           NaN           NaN
#  1           NaN       NaN        NaN        NaN  2.415086e+06           NaN
#  2           NaN       NaN        NaN        NaN  1.174845e+07           NaN
#  3           NaN       NaN        NaN        NaN -1.072424e+07           NaN
#  4           NaN       NaN        NaN        NaN -7.326356e+06           NaN
#  ...         ...       ...        ...        ...           ...           ...
#  1902  38.721429  0.310828  23.712356  41.327363  6.154424e+06 -1.092125e+08
#  1903  36.785714  0.466408  31.806144  46.935174  1.172352e+08 -7.686285e+07
#  1904  36.550000  0.469416  31.945737  46.464915 -9.845417e+06 -6.728893e+07
#  1905  30.975000  0.738038  42.463845  52.294983  1.765713e+08 -3.245176e+07
#  1906  33.135714  0.689912  40.825308  49.039402 -5.065971e+07 -3.505289e+07
#
#  [1907 rows x 27 columns],
#  'ADANIENT_minute':              datec          date    close     high      low     open  volume  \
#  0       2015-02-02  16468.156250   662.00   662.00   646.90   646.90  271571
#  1       2015-02-02  16468.156944   653.90   662.30   653.60   661.70  193089
#  2       2015-02-02  16468.157639   657.95   658.00   651.05   654.20   89069
#  3       2015-02-02  16468.158333   656.80   657.50   655.40   657.00   68028
#  4       2015-02-02  16468.159028   647.00   656.95   647.00   656.95  105605
#  ...            ...           ...      ...      ...      ...      ...     ...
#  660534  2022-10-24  19289.569444  3310.95  3312.95  3310.00  3310.15    2893
#  660535  2022-10-24  19289.570139  3315.00  3315.40  3310.00  3311.55    3268
#  660536  2022-10-24  19289.570833  3314.00  3318.95  3314.00  3315.40   11299
#  660537  2022-10-24  19289.571528  3319.00  3319.00  3314.00  3314.55    8642
#  660538  2022-10-24  19289.572222  3320.00  3320.90  3315.60  3319.00    7317
#
#          VolumePositive  Doji  IsDoji  ...  macdhist  Gain  Loss  AVG_Gain  \
#  0                 True     0   False  ...       NaN   NaN   NaN       NaN
#  1                False     0   False  ...       NaN  0.00  8.10       NaN
#  2                 True     0   False  ...       NaN  4.05  0.00       NaN
#  3                False     0   False  ...       NaN  0.00  1.15       NaN
#  4                False     0   False  ...       NaN  0.00  9.80       NaN
#  ...                ...   ...     ...  ...       ...   ...   ...       ...
#  660534            True     0   False  ...  0.759044  0.95  0.00  1.278571
#  660535            True     0   False  ...  1.391366  4.05  0.00  1.439286
#  660536           False     0   False  ...  1.698862  0.00  1.00  1.439286
#  660537            True     0   False  ...  2.165679  5.00  0.00  1.796429
#  660538            True     0   False  ...  2.447676  1.00  0.00  1.867857
#
#          AVG_Loss        RS        RSI     RSI_ta        FI_1        FI_13
#  0            NaN       NaN        NaN        NaN         NaN          NaN
#  1            NaN       NaN        NaN        NaN -1564020.90          NaN
#  2            NaN       NaN        NaN        NaN   360729.45          NaN
#  3            NaN       NaN        NaN        NaN   -78232.20          NaN
#  4            NaN       NaN        NaN        NaN -1034929.00          NaN
#  ...          ...       ...        ...        ...         ...          ...
#  660534  2.007143  0.637011  38.913043  47.744359     2748.35 -2203.228854
#  660535  2.007143  0.717082  41.761658  53.845216    13235.40     2.289554
#  660536  1.546429  0.930716  48.205742  52.223940   -11299.00 -1612.180383
#  660537  1.403571  1.279898  56.138393  58.889244    43210.00  4790.988244
#  660538  0.914286  2.042969  67.137356  60.088528     7317.00  5151.847066
#
#  [660539 rows x 27 columns],
#  'ADANIGREEN_60minute':            datec          date    close     high      low     open   volume  \
#  0     2018-06-18  17700.156250    29.00    30.70    28.50    30.00  3969889
#  1     2018-06-18  17700.197917    31.00    31.50    29.00    29.00   823998
#  2     2018-06-18  17700.239583    31.25    31.50    30.70    31.00   322539
#  3     2018-06-18  17700.281250    31.20    31.50    29.70    31.25  1521750
#  4     2018-06-18  17700.322917    31.50    31.50    31.00    31.50   219945
#  ...          ...           ...      ...      ...      ...      ...      ...
#  7222  2022-10-21  19286.239583  2135.85  2150.00  2131.15  2146.45   182439
#  7223  2022-10-21  19286.281250  2141.95  2142.05  2121.00  2135.85    69835
#  7224  2022-10-21  19286.322917  2135.00  2150.00  2122.00  2141.95   144891
#  7225  2022-10-21  19286.364583  2096.20  2138.10  2075.25  2135.00  2689810
#  7226  2022-10-21  19286.406250  2106.90  2120.00  2092.90  2096.20  2030983
#
#        VolumePositive  Doji  IsDoji  ...  macdhist   Gain   Loss  AVG_Gain  \
#  0              False     0   False  ...       NaN    NaN    NaN       NaN
#  1               True     0   False  ...       NaN   2.00   0.00       NaN
#  2               True     0   False  ...       NaN   0.25   0.00       NaN
#  3              False     0   False  ...       NaN   0.00   0.05       NaN
#  4              False     0   False  ...       NaN   0.30   0.00       NaN
#  ...              ...   ...     ...  ...       ...    ...    ...       ...
#  7222           False     0   False  ...  1.656936   0.00  10.60  4.742857
#  7223            True     0   False  ...  1.615954   6.10   0.00  5.178571
#  7224           False     0   False  ...  1.052945   0.00   6.95  5.171429
#  7225           False     0   False  ... -1.842740   0.00  38.80  5.171429
#  7226            True     0   False  ... -2.885528  10.70   0.00  5.735714
#
#        AVG_Loss        RS        RSI     RSI_ta          FI_1         FI_13
#  0          NaN       NaN        NaN        NaN           NaN           NaN
#  1          NaN       NaN        NaN        NaN  1.647996e+06           NaN
#  2          NaN       NaN        NaN        NaN  8.063475e+04           NaN
#  3          NaN       NaN        NaN        NaN -7.608750e+04           NaN
#  4          NaN       NaN        NaN        NaN  6.598350e+04           NaN
#  ...        ...       ...        ...        ...           ...           ...
#  7222  4.907143  0.966521  49.148779  50.994365 -1.933853e+06  2.208051e+05
#  7223  3.742857  1.383588  58.046437  52.968323  4.259935e+05  2.501177e+05
#  7224  4.239286  1.219882  54.952562  50.473745 -1.006992e+06  7.053054e+04
#  7225  6.878571  0.751817  42.916420  39.335894 -1.043646e+08 -1.484878e+07
#  7226  6.878571  0.833853  45.469989  43.066993  2.173152e+07 -9.623021e+06
#
#  [7227 rows x 27 columns],
#  'ADANIGREEN_day':            datec          date    close     high      low     open   volume  \
#  0     2018-06-18  17699.770833    31.50    31.50    28.50    30.00  7006229
#  1     2018-06-19  17700.770833    32.60    33.05    31.00    32.70  2895692
#  2     2018-06-20  17701.770833    31.00    32.20    31.00    31.50  1115553
#  3     2018-06-21  17702.770833    29.65    30.00    29.45    29.45  2854524
#  4     2018-06-22  17703.770833    29.45    29.80    28.20    28.20  1612972
#  ...          ...           ...      ...      ...      ...      ...      ...
#  1058  2022-10-17  19281.770833  2154.45  2198.00  2035.00  2044.10  2910329
#  1059  2022-10-18  19282.770833  2153.75  2215.40  2135.00  2184.40  2404969
#  1060  2022-10-19  19283.770833  2119.80  2181.75  2105.00  2169.00  1373248
#  1061  2022-10-20  19284.770833  2138.90  2151.00  2090.00  2101.00  1003651
#  1062  2022-10-21  19285.770833  2105.30  2164.50  2075.25  2149.60  5902738
#
#        VolumePositive  Doji  IsDoji  ...  macdhist   Gain   Loss   AVG_Gain  \
#  0               True     0   False  ...       NaN    NaN    NaN        NaN
#  1              False     0   False  ...       NaN    1.1   0.00        NaN
#  2              False     0   False  ...       NaN    0.0   1.60        NaN
#  3               True     0   False  ...       NaN    0.0   1.35        NaN
#  4               True     0   False  ...       NaN    0.0   0.20        NaN
#  ...              ...   ...     ...  ...       ...    ...    ...        ...
#  1058            True     0   False  ... -6.101768  121.3   0.00  36.296429
#  1059           False     0   False  ... -0.993881    0.0   0.70  36.296429
#  1060           False     0   False  ...  0.492402    0.0  33.95  36.296429
#  1061            True     0   False  ...  3.015224   19.1   0.00  37.660714
#  1062           False     0   False  ...  2.685415    0.0  33.60  19.321429
#
#         AVG_Loss        RS        RSI     RSI_ta          FI_1         FI_13
#  0           NaN       NaN        NaN        NaN           NaN           NaN
#  1           NaN       NaN        NaN        NaN  3.185261e+06           NaN
#  2           NaN       NaN        NaN        NaN -1.784885e+06           NaN
#  3           NaN       NaN        NaN        NaN -3.853607e+06           NaN
#  4           NaN       NaN        NaN        NaN -3.225944e+05           NaN
#  ...         ...       ...        ...        ...           ...           ...
#  1058  40.289286  0.900895  47.393210  47.696401  3.530229e+08  6.881924e+07
#  1059  35.764286  1.014879  50.369232  47.653960 -1.683478e+06  5.874742e+07
#  1060  31.385714  1.156463  53.627777  45.537561 -4.662177e+07  4.369468e+07
#  1061  28.028571  1.343654  57.331594  46.964622  1.916973e+07  4.019112e+07
#  1062  30.428571  0.634977  38.837042  44.743532 -1.983320e+08  6.116388e+06
#
#  [1063 rows x 27 columns],
#  'ADANIGREEN_minute':              datec          date    close     high      low    open   volume  \
#  0       2018-06-18  17700.176389    30.00    30.00    30.00    30.0  1413185
#  1       2018-06-18  17700.177083    30.00    30.00    30.00    30.0        0
#  2       2018-06-18  17700.177778    30.00    30.00    30.00    30.0        0
#  3       2018-06-18  17700.178472    30.00    30.00    30.00    30.0        0
#  4       2018-06-18  17700.179167    30.00    30.00    30.00    30.0        0
#  ...            ...           ...      ...      ...      ...     ...      ...
#  370630  2022-10-24  19289.569444  2126.70  2127.00  2123.85  2125.0      680
#  370631  2022-10-24  19289.570139  2129.00  2129.80  2126.30  2126.7     2511
#  370632  2022-10-24  19289.570833  2129.05  2129.85  2127.00  2129.0     1102
#  370633  2022-10-24  19289.571528  2125.00  2129.80  2125.00  2129.0     1632
#  370634  2022-10-24  19289.572222  2128.00  2129.00  2120.80  2125.0      767
#
#          VolumePositive  Doji  IsDoji  ...  macdhist  Gain  Loss  AVG_Gain  \
#  0                False     0   False  ...       NaN   NaN   NaN       NaN
#  1                False     0   False  ...       NaN  0.00  0.00       NaN
#  2                False     0   False  ...       NaN  0.00  0.00       NaN
#  3                False     0   False  ...       NaN  0.00  0.00       NaN
#  4                False     0   False  ...       NaN  0.00  0.00       NaN
#  ...                ...   ...     ...  ...       ...   ...   ...       ...
#  370630            True     0   False  ...  0.803278  1.70  0.00  0.875000
#  370631            True     0   False  ...  1.036908  2.30  0.00  1.039286
#  370632            True   100    True  ...  1.128422  0.05  0.00  0.975000
#  370633           False     0   False  ...  0.861838  0.00  4.05  0.967857
#  370634            True     0   False  ...  0.832731  3.00  0.00  1.182143
#
#          AVG_Loss        RS        RSI     RSI_ta    FI_1       FI_13
#  0            NaN       NaN        NaN        NaN     NaN         NaN
#  1            NaN       NaN        NaN        NaN     0.0         NaN
#  2            NaN       NaN        NaN        NaN     0.0         NaN
#  3            NaN       NaN        NaN        NaN     0.0         NaN
#  4            NaN       NaN        NaN        NaN     0.0         NaN
#  ...          ...       ...        ...        ...     ...         ...
#  370630  0.396429  2.207207  68.820225  66.310142  1156.0 -884.928713
#  370631  0.378571  2.745283  73.299748  70.193282  5775.3   66.532532
#  370632  0.378571  2.575472  72.031662  70.273497    55.1   64.899313
#  370633  0.667857  1.449198  59.170306  56.913026 -6609.6 -888.600589
#  370634  0.610714  1.935673  65.936255  62.587185  2301.0 -432.943362
#
#  [370635 rows x 27 columns],
#  'ADANIPORTS_60minute':             datec          date   close    high     low    open  volume  \
#  0      2015-02-02  16468.156250  335.30  343.90  333.00  338.85  536138
#  1      2015-02-02  16468.197917  338.70  342.50  335.15  335.30  358874
#  2      2015-02-02  16468.239583  336.60  339.45  335.60  338.70  166898
#  3      2015-02-02  16468.281250  336.55  338.05  335.50  336.70   97053
#  4      2015-02-02  16468.322917  336.40  337.75  335.65  336.55  111281
#  ...           ...           ...     ...     ...     ...     ...     ...
#  12769  2022-10-21  19286.239583  811.20  815.55  809.00  812.20  543954
#  12770  2022-10-21  19286.281250  807.00  811.50  806.00  811.45  461592
#  12771  2022-10-21  19286.322917  805.00  807.50  801.25  807.00  976908
#  12772  2022-10-21  19286.364583  801.90  805.90  801.20  804.90  834272
#  12773  2022-10-21  19286.406250  800.60  802.50  799.40  801.80  526981
#
#         VolumePositive  Doji  IsDoji  ...  macdhist  Gain  Loss  AVG_Gain  \
#  0               False     0   False  ...       NaN   NaN   NaN       NaN
#  1                True     0   False  ...       NaN   3.4  0.00       NaN
#  2               False     0   False  ...       NaN   0.0  2.10       NaN
#  3               False     0   False  ...       NaN   0.0  0.05       NaN
#  4               False     0   False  ...       NaN   0.0  0.15       NaN
#  ...               ...   ...     ...  ...       ...   ...   ...       ...
#  12769           False     0   False  ... -0.149760   0.0  1.00  1.482143
#  12770           False     0   False  ... -0.707608   0.0  4.20  1.482143
#  12771           False     0   False  ... -1.183196   0.0  2.00  1.482143
#  12772           False     0   False  ... -1.649797   0.0  3.10  1.482143
#  12773           False     0   False  ... -1.967672   0.0  1.30  1.253571
#
#         AVG_Loss        RS        RSI     RSI_ta        FI_1          FI_13
#  0           NaN       NaN        NaN        NaN         NaN            NaN
#  1           NaN       NaN        NaN        NaN  1220171.60            NaN
#  2           NaN       NaN        NaN        NaN  -350485.80            NaN
#  3           NaN       NaN        NaN        NaN    -4852.65            NaN
#  4           NaN       NaN        NaN        NaN   -16692.15            NaN
#  ...         ...       ...        ...        ...         ...            ...
#  12769  1.792857  0.826693  45.256270  53.164057  -543954.00  264678.052931
#  12770  1.596429  0.928412  48.143852  48.480063 -1938686.40  -50088.297488
#  12771  1.725000  0.859213  46.213808  46.384335 -1953816.00 -322049.397847
#  12772  1.675000  0.884861  46.945701  43.262568 -2586243.20 -645505.655297
#  12773  1.767857  0.709091  41.489362  41.986411  -685075.30 -651158.461683
#
#  [12774 rows x 27 columns],
#  'ADANIPORTS_day':            datec          date   close    high     low    open   volume  \
#  0     2015-01-01  16435.770833  319.55  322.50  316.25  319.00  1456204
#  1     2015-01-02  16436.770833  319.35  325.80  318.05  319.35  2894058
#  2     2015-01-05  16439.770833  323.80  327.50  319.35  320.45  2099786
#  3     2015-01-06  16440.770833  321.85  331.45  315.60  321.64  3672197
#  4     2015-01-07  16441.770833  321.10  328.70  317.39  321.95  2981544
#  ...          ...           ...     ...     ...     ...     ...      ...
#  1902  2022-10-17  19281.770833  786.20  789.95  771.65  782.10  4602870
#  1903  2022-10-18  19282.770833  809.95  815.00  790.50  791.45  7372253
#  1904  2022-10-19  19283.770833  805.05  823.45  801.15  814.00  5222275
#  1905  2022-10-20  19284.770833  820.05  822.25  795.05  801.00  4481441
#  1906  2022-10-21  19285.770833  801.65  824.20  799.40  824.20  5266210
#
#        VolumePositive  Doji  IsDoji  ...  macdhist   Gain   Loss  AVG_Gain  \
#  0               True     0   False  ...       NaN    NaN    NaN       NaN
#  1              False     0   False  ...       NaN   0.00   0.20       NaN
#  2               True     0   False  ...       NaN   4.45   0.00       NaN
#  3               True     0   False  ...       NaN   0.00   1.95       NaN
#  4              False     0   False  ...       NaN   0.00   0.75       NaN
#  ...              ...   ...     ...  ...       ...    ...    ...       ...
#  1902            True     0   False  ... -8.005194   6.10   0.00  4.042857
#  1903            True     0   False  ... -5.078069  23.75   0.00  5.739286
#  1904           False     0   False  ... -3.142165   0.00   4.90  5.739286
#  1905            True     0   False  ... -0.651889  15.00   0.00  6.810714
#  1906           False     0   False  ... -0.074712   0.00  18.40  6.507143
#
#        AVG_Loss        RS        RSI     RSI_ta          FI_1         FI_13
#  0          NaN       NaN        NaN        NaN           NaN           NaN
#  1          NaN       NaN        NaN        NaN -5.788116e+05           NaN
#  2          NaN       NaN        NaN        NaN  9.344048e+06           NaN
#  3          NaN       NaN        NaN        NaN -7.160784e+06           NaN
#  4          NaN       NaN        NaN        NaN -2.236158e+06           NaN
#  ...        ...       ...        ...        ...           ...           ...
#  1902  9.557143  0.423019  29.726891  37.623892  2.807751e+07 -3.790050e+07
#  1903  8.185714  0.701134  41.215696  44.454236  1.750910e+08 -7.473141e+06
#  1904  7.314286  0.784668  43.967168  43.398355 -2.558915e+07 -1.006114e+07
#  1905  6.550000  1.039804  50.975675  47.508616  6.722162e+07  9.792522e+05
#  1906  7.864286  0.827430  45.278330  43.350071 -9.689826e+07 -1.300325e+07
#
#  [1907 rows x 27 columns],
#  'ADANIPORTS_minute':              datec          date   close    high     low    open  volume  \
#  0       2015-02-02  16468.156250  341.40  342.40  338.85  338.85   46482
#  1       2015-02-02  16468.156944  342.85  343.90  341.35  341.90   45324
#  2       2015-02-02  16468.157639  342.20  342.85  341.50  342.85   21503
#  3       2015-02-02  16468.158333  342.55  342.80  342.00  342.20   21984
#  4       2015-02-02  16468.159028  340.65  342.55  340.40  342.55   14631
#  ...            ...           ...     ...     ...     ...     ...     ...
#  671091  2022-10-24  19289.569444  806.25  806.50  806.00  806.20    3038
#  671092  2022-10-24  19289.570139  807.15  807.15  806.25  806.25    6503
#  671093  2022-10-24  19289.570833  808.90  809.00  807.15  807.50   11421
#  671094  2022-10-24  19289.571528  809.10  809.65  808.55  808.55   19955
#  671095  2022-10-24  19289.572222  807.95  809.20  806.25  809.20    9096
#
#          VolumePositive  Doji  IsDoji  ...  macdhist  Gain  Loss  AVG_Gain  \
#  0                 True     0   False  ...       NaN   NaN   NaN       NaN
#  1                 True     0   False  ...       NaN  1.45  0.00       NaN
#  2                False     0   False  ...       NaN  0.00  0.65       NaN
#  3                 True     0   False  ...       NaN  0.35  0.00       NaN
#  4                False     0   False  ...       NaN  0.00  1.90       NaN
#  ...                ...   ...     ...  ...       ...   ...   ...       ...
#  671091            True   100    True  ...  0.231386  0.05  0.00  0.342857
#  671092            True     0   False  ...  0.337337  0.90  0.00  0.371429
#  671093            True     0   False  ...  0.501004  1.75  0.00  0.496429
#  671094            True     0   False  ...  0.592209  0.20  0.00  0.510714
#  671095           False     0   False  ...  0.545710  0.00  1.15  0.510714
#
#          AVG_Loss        RS        RSI     RSI_ta      FI_1        FI_13
#  0            NaN       NaN        NaN        NaN       NaN          NaN
#  1            NaN       NaN        NaN        NaN  65719.80          NaN
#  2            NaN       NaN        NaN        NaN -13976.95          NaN
#  3            NaN       NaN        NaN        NaN   7694.40          NaN
#  4            NaN       NaN        NaN        NaN -27798.90          NaN
#  ...          ...       ...        ...        ...       ...          ...
#  671091  0.296429  1.156627  53.631285  56.922597    151.90 -1701.000513
#  671092  0.296429  1.253012  55.614973  61.441925   5852.70  -621.900440
#  671093  0.267857  1.853333  64.953271  68.386913  19986.75  2322.192480
#  671094  0.267857  1.906667  65.596330  69.072523   3991.00  2560.593554
#  671095  0.339286  1.505263  60.084034  60.894622 -10460.40   700.451618
#
#  [671096 rows x 27 columns],
#  'AMBUJACEM_60minute':             datec          date   close    high     low    open   volume  \
#  0      2015-02-02  16468.156250  246.70  250.00  246.25  250.00   140603
#  1      2015-02-02  16468.197917  245.25  247.00  245.00  246.70    64735
#  2      2015-02-02  16468.239583  244.85  245.80  243.55  245.25   100565
#  3      2015-02-02  16468.281250  245.65  245.95  244.50  245.00   103465
#  4      2015-02-02  16468.322917  250.00  250.80  245.10  245.65   165315
#  ...           ...           ...     ...     ...     ...     ...      ...
#  12769  2022-10-21  19286.239583  513.40  515.85  512.35  515.45   856504
#  12770  2022-10-21  19286.281250  510.40  513.40  507.50  513.30   773784
#  12771  2022-10-21  19286.322917  512.30  512.80  504.30  510.45  1697582
#  12772  2022-10-21  19286.364583  512.25  520.40  510.30  511.85  3155810
#  12773  2022-10-21  19286.406250  513.20  513.85  511.25  512.20   791404
#
#         VolumePositive  Doji  IsDoji  ...  macdhist  Gain  Loss  AVG_Gain  \
#  0               False     0   False  ...       NaN   NaN   NaN       NaN
#  1               False     0   False  ...       NaN  0.00  1.45       NaN
#  2               False     0   False  ...       NaN  0.00  0.40       NaN
#  3                True     0   False  ...       NaN  0.80  0.00       NaN
#  4                True     0   False  ...       NaN  4.35  0.00       NaN
#  ...               ...   ...     ...  ...       ...   ...   ...       ...
#  12769           False     0   False  ...  0.098305  0.00  2.00  1.128571
#  12770           False     0   False  ... -0.267505  0.00  3.00  1.085714
#  12771            True     0   False  ... -0.375445  1.90  0.00  1.221429
#  12772            True   100    True  ... -0.439688  0.00  0.05  1.221429
#  12773            True     0   False  ... -0.408354  0.95  0.00  1.239286
#
#         AVG_Loss        RS        RSI     RSI_ta        FI_1          FI_13
#  0           NaN       NaN        NaN        NaN         NaN            NaN
#  1           NaN       NaN        NaN        NaN   -93865.75            NaN
#  2           NaN       NaN        NaN        NaN   -40226.00            NaN
#  3           NaN       NaN        NaN        NaN    82772.00            NaN
#  4           NaN       NaN        NaN        NaN   719120.25            NaN
#  ...         ...       ...        ...        ...         ...            ...
#  12769  1.128571  1.000000  50.000000  51.434594 -1713008.00  768158.659249
#  12770  1.342857  0.808511  44.705882  47.158122 -2321352.00  326799.993642
#  12771  1.271429  0.960674  48.997135  49.993888  3225405.80  740886.537407
#  12772  1.071429  1.140000  53.271028  49.917969  -157790.50  612504.103492
#  12773  1.071429  1.156667  53.632148  51.427231   751833.80  632408.345850
#
#  [12774 rows x 27 columns],
#  'AMBUJACEM_day':            datec          date   close    high     low    open    volume  \
#  0     2015-01-01  16435.770833  227.75  229.45  227.50  229.00    208341
#  1     2015-01-02  16436.770833  230.95  231.70  228.00  228.00    582581
#  2     2015-01-05  16439.770833  230.65  233.30  229.55  230.95    967248
#  3     2015-01-06  16440.770833  222.15  230.00  220.75  230.00   1479156
#  4     2015-01-07  16441.770833  220.10  222.95  218.10  222.00   1172388
#  ...          ...           ...     ...     ...     ...     ...       ...
#  1902  2022-10-17  19281.770833  520.55  522.70  497.45  499.00   9626670
#  1903  2022-10-18  19282.770833  507.85  524.20  506.05  523.00  10116195
#  1904  2022-10-19  19283.770833  510.70  519.00  506.70  511.00   6646701
#  1905  2022-10-20  19284.770833  517.70  519.00  507.00  509.00   5223412
#  1906  2022-10-21  19285.770833  512.60  522.90  503.80  518.00   9693780
#
#        VolumePositive  Doji  IsDoji  ...  macdhist   Gain   Loss  AVG_Gain  \
#  0              False     0   False  ...       NaN    NaN    NaN       NaN
#  1               True     0   False  ...       NaN   3.20   0.00       NaN
#  2              False     0   False  ...       NaN   0.00   0.30       NaN
#  3              False     0   False  ...       NaN   0.00   8.50       NaN
#  4              False     0   False  ...       NaN   0.00   2.05       NaN
#  ...              ...   ...     ...  ...       ...    ...    ...       ...
#  1902            True     0   False  ... -4.369285  18.70   0.00  5.607143
#  1903           False     0   False  ... -4.154951   0.00  12.70  5.607143
#  1904           False   100    True  ... -3.749645   2.85   0.00  5.810714
#  1905            True     0   False  ... -2.972499   7.00   0.00  5.860714
#  1906           False     0   False  ... -2.768448   0.00   5.10  5.200000
#
#        AVG_Loss        RS        RSI     RSI_ta          FI_1         FI_13
#  0          NaN       NaN        NaN        NaN           NaN           NaN
#  1          NaN       NaN        NaN        NaN  1.864259e+06           NaN
#  2          NaN       NaN        NaN        NaN -2.901744e+05           NaN
#  3          NaN       NaN        NaN        NaN -1.257283e+07           NaN
#  4          NaN       NaN        NaN        NaN -2.403395e+06           NaN
#  ...        ...       ...        ...        ...           ...           ...
#  1902  4.939286  1.135213  53.166272  57.689888  1.800187e+08  3.724596e+07
#  1903  5.357143  1.046667  51.140065  53.397522 -1.284757e+08  1.357144e+07
#  1904  5.050000  1.150636  53.502137  54.220697  1.894310e+07  1.433882e+07
#  1905  5.050000  1.160537  53.715221  56.264122  3.656388e+07  1.751383e+07
#  1906  5.414286  0.960422  48.990579  54.360292 -4.943828e+07  7.949240e+06
#
#  [1907 rows x 27 columns],
#  'AMBUJACEM_minute':              datec          date   close    high     low    open  volume  \
#  0       2015-02-02  16468.156250  249.35  250.00  248.45  250.00    9534
#  1       2015-02-02  16468.156944  248.30  249.35  248.30  249.35    3188
#  2       2015-02-02  16468.157639  247.95  248.30  247.75  248.30    3179
#  3       2015-02-02  16468.158333  247.80  248.00  247.60  248.00    4980
#  4       2015-02-02  16468.159028  247.80  247.90  247.65  247.80    1986
#  ...            ...           ...     ...     ...     ...     ...     ...
#  665844  2022-10-24  19289.569444  517.00  517.20  516.75  516.85    6239
#  665845  2022-10-24  19289.570139  517.35  517.40  516.75  517.00    9079
#  665846  2022-10-24  19289.570833  517.15  517.45  517.10  517.30    9770
#  665847  2022-10-24  19289.571528  517.05  517.30  517.00  517.30   11428
#  665848  2022-10-24  19289.572222  517.00  517.25  516.50  517.10   17646
#
#          VolumePositive  Doji  IsDoji  ...  macdhist  Gain  Loss  AVG_Gain  \
#  0                False     0   False  ...       NaN   NaN   NaN       NaN
#  1                False     0   False  ...       NaN  0.00  1.05       NaN
#  2                False     0   False  ...       NaN  0.00  0.35       NaN
#  3                False     0   False  ...       NaN  0.00  0.15       NaN
#  4                False     0   False  ...       NaN  0.00  0.00       NaN
#  ...                ...   ...     ...  ...       ...   ...   ...       ...
#  665844            True     0   False  ... -0.003845  0.00  0.00  0.135714
#  665845            True     0   False  ...  0.029112  0.35  0.00  0.160714
#  665846           False     0   False  ...  0.035799  0.00  0.20  0.160714
#  665847           False     0   False  ...  0.031970  0.00  0.10  0.139286
#  665848           False     0   False  ...  0.024868  0.00  0.05  0.139286
#
#          AVG_Loss        RS        RSI     RSI_ta     FI_1        FI_13
#  0            NaN       NaN        NaN        NaN      NaN          NaN
#  1            NaN       NaN        NaN        NaN -3347.40          NaN
#  2            NaN       NaN        NaN        NaN -1112.65          NaN
#  3            NaN       NaN        NaN        NaN  -747.00          NaN
#  4            NaN       NaN        NaN        NaN     0.00          NaN
#  ...          ...       ...        ...        ...      ...          ...
#  665844  0.164286  0.826087  45.238095  50.826075     0.00 -1037.896241
#  665845  0.157143  1.022727  50.561798  54.735085  3177.65  -435.675349
#  665846  0.153571  1.046512  51.136364  52.182370 -1954.00  -652.578871
#  665847  0.160714  0.866667  46.428571  50.904038 -1142.80  -722.610461
#  665848  0.153571  0.906977  47.560976  50.241310  -882.30  -745.423252
#
#  [665849 rows x 27 columns],
#  'APOLLOHOSP_60minute':             datec          date    close     high      low     open  volume  \
#  0      2015-02-02  16468.156250  1341.05  1350.00  1310.10  1350.00   27545
#  1      2015-02-02  16468.197917  1341.35  1346.90  1340.00  1341.05   11722
#  2      2015-02-02  16468.239583  1338.95  1341.80  1330.10  1341.35   16843
#  3      2015-02-02  16468.281250  1337.95  1339.40  1336.35  1338.95   37263
#  4      2015-02-02  16468.322917  1338.00  1339.20  1335.00  1337.95   35798
#  ...           ...           ...      ...      ...      ...      ...     ...
#  12769  2022-10-21  19286.239583  4412.80  4430.00  4394.05  4400.20   61281
#  12770  2022-10-21  19286.281250  4406.20  4420.00  4396.00  4415.50   35586
#  12771  2022-10-21  19286.322917  4396.15  4408.00  4390.00  4406.20   31028
#  12772  2022-10-21  19286.364583  4390.25  4398.65  4372.00  4397.50   88237
#  12773  2022-10-21  19286.406250  4390.00  4394.45  4386.45  4390.65   24116
#
#         VolumePositive  Doji  IsDoji  ...  macdhist  Gain   Loss  AVG_Gain  \
#  0               False     0   False  ...       NaN   NaN    NaN       NaN
#  1                True     0   False  ...       NaN  0.30   0.00       NaN
#  2               False     0   False  ...       NaN  0.00   2.40       NaN
#  3               False     0   False  ...       NaN  0.00   1.00       NaN
#  4                True     0   False  ...       NaN  0.05   0.00       NaN
#  ...               ...   ...     ...  ...       ...   ...    ...       ...
#  12769            True     0   False  ...  3.734152  9.80   0.00  8.553571
#  12770           False     0   False  ...  4.701514  0.00   6.60  8.553571
#  12771           False     0   False  ...  4.300293  0.00  10.05  7.892857
#  12772           False     0   False  ...  3.317345  0.00   5.90  7.407143
#  12773           False   100    True  ...  2.374319  0.00   0.25  7.407143
#
#         AVG_Loss        RS        RSI     RSI_ta      FI_1          FI_13
#  0           NaN       NaN        NaN        NaN       NaN            NaN
#  1           NaN       NaN        NaN        NaN    3516.6            NaN
#  2           NaN       NaN        NaN        NaN  -40423.2            NaN
#  3           NaN       NaN        NaN        NaN  -37263.0            NaN
#  4           NaN       NaN        NaN        NaN    1789.9            NaN
#  ...         ...       ...        ...        ...       ...            ...
#  12769  6.210714  1.377228  57.934204  67.081372  600553.8  705597.794751
#  12770  6.321429  1.353107  57.503001  64.817885 -234867.6  571245.595501
#  12771  7.039286  1.121258  52.858168  61.419378 -311831.4  445091.739001
#  12772  7.460714  0.992820  49.819841  59.448741 -520598.3  307136.019144
#  12773  7.332143  1.010229  50.254422  59.361829   -6029.0  262398.159266
#
#  [12774 rows x 27 columns],
#  'APOLLOHOSP_day':            datec          date    close     high      low     open  volume  \
#  0     2015-01-01  16435.770833  1125.90  1137.00  1119.00  1131.00   76848
#  1     2015-01-02  16436.770833  1127.84  1139.00  1123.55  1125.05  172991
#  2     2015-01-05  16439.770833  1131.59  1144.50  1126.05  1127.84  137885
#  3     2015-01-06  16440.770833  1097.90  1135.59  1090.75  1129.55  164585
#  4     2015-01-07  16441.770833  1106.50  1114.00  1079.75  1110.00  208499
#  ...          ...           ...      ...      ...      ...      ...     ...
#  1902  2022-10-17  19281.770833  4290.85  4300.55  4221.05  4290.00  254734
#  1903  2022-10-18  19282.770833  4366.00  4377.00  4258.00  4325.00  387469
#  1904  2022-10-19  19283.770833  4388.75  4405.90  4341.10  4380.00  249672
#  1905  2022-10-20  19284.770833  4322.50  4393.30  4295.20  4384.00  370651
#  1906  2022-10-21  19285.770833  4389.05  4430.00  4322.70  4344.15  364601
#
#        VolumePositive  Doji  IsDoji  ...   macdhist   Gain   Loss   AVG_Gain  \
#  0              False     0   False  ...        NaN    NaN    NaN        NaN
#  1               True     0   False  ...        NaN   1.94   0.00        NaN
#  2               True     0   False  ...        NaN   3.75   0.00        NaN
#  3              False     0   False  ...        NaN   0.00  33.69        NaN
#  4              False     0   False  ...        NaN   8.60   0.00        NaN
#  ...              ...   ...     ...  ...        ...    ...    ...        ...
#  1902            True   100    True  ... -16.118216   0.00   6.30  16.725000
#  1903            True     0   False  ...  -9.485952  75.15   0.00  22.092857
#  1904            True   100    True  ...  -3.386161  22.75   0.00  21.860714
#  1905           False     0   False  ...  -3.611929   0.00  66.25  13.092857
#  1906            True     0   False  ...   0.692618  66.55   0.00  17.846429
#
#         AVG_Loss        RS        RSI     RSI_ta         FI_1         FI_13
#  0           NaN       NaN        NaN        NaN          NaN           NaN
#  1           NaN       NaN        NaN        NaN    335602.54           NaN
#  2           NaN       NaN        NaN        NaN    517068.75           NaN
# ...
#
#         VolumePositive  Doji  IsDoji  ...  macdhist  Gain  Loss  AVG_Gain  \
#  0                True     0   False  ...       NaN   NaN   NaN       NaN
#  1                True     0   False  ...       NaN  0.53   0.0       NaN
#  2                True     0   False  ...       NaN  0.89   0.0       NaN
#  3                True     0   False  ...       NaN  0.72   0.0       NaN
#  4                True     0   False  ...       NaN  0.48   0.0       NaN
#  ...               ...   ...     ...  ...       ...   ...   ...       ...
#  12769            True     0   False  ...  0.595518  0.65   0.0  0.478571
#  12770            True   100    True  ...  0.552132  0.15   0.0  0.489286
#  12771           False     0   False  ...  0.475544  0.00   0.4  0.478571
#  12772            True     0   False  ...  0.451276  0.70   0.0  0.510714
#  12773            True     0   False  ...  0.428136  0.20   0.0  0.510714
#
#         AVG_Loss        RS        RSI     RSI_ta        FI_1          FI_13
#  0           NaN       NaN        NaN        NaN         NaN            NaN
#  1           NaN       NaN        NaN        NaN   294978.92            NaN
#  2           NaN       NaN        NaN        NaN  1142631.84            NaN
#  3           NaN       NaN        NaN        NaN   496778.40            NaN
#  4           NaN       NaN        NaN        NaN   403488.00            NaN
#  ...         ...       ...        ...        ...         ...            ...
#  12769  0.296429  1.614458  61.751152  52.926075   314124.85  245462.218968
#  12770  0.175000  2.795918  73.655914  53.463726    45527.85  216900.166258
#  12771  0.203571  2.350877  70.157068  51.765808  -271150.00  147178.713935
#  12772  0.203571  2.508772  71.500000  54.489701   678460.30  223076.083373
#  12773  0.203571  2.508772  71.500000  55.266985   100294.00  205535.785748
#
#  [12774 rows x 27 columns],
#  'WIPRO_day':            datec          date   close    high     low    open    volume  \
#  0     2015-01-01  16435.770833  207.67  208.42  206.95  207.72    405956
#  1     2015-01-02  16436.770833  209.51  210.62  207.89  208.05   1574608
#  2     2015-01-05  16439.770833  209.89  212.41  208.83  209.41   1439476
#  3     2015-01-06  16440.770833  204.98  209.17  203.80  208.65   4648762
#  4     2015-01-07  16441.770833  203.42  204.89  202.39  204.21   3114594
#  ...          ...           ...     ...     ...     ...     ...       ...
#  1902  2022-10-17  19281.770833  375.10  378.95  372.40  377.30   8454769
#  1903  2022-10-18  19282.770833  379.30  384.25  378.40  383.70  11164240
#  1904  2022-10-19  19283.770833  378.05  381.20  377.05  381.20   5099139
#  1905  2022-10-20  19284.770833  381.50  382.60  376.00  377.00   5934407
#  1906  2022-10-21  19285.770833  382.55  383.30  380.20  382.50   4465770
#
#        VolumePositive  Doji  IsDoji  ...  macdhist  Gain  Loss  AVG_Gain  \
#  0              False     0   False  ...       NaN   NaN   NaN       NaN
#  1               True     0   False  ...       NaN  1.84  0.00       NaN
#  2               True     0   False  ...       NaN  0.38  0.00       NaN
#  3              False     0   False  ...       NaN  0.00  4.91       NaN
#  4              False     0   False  ...       NaN  0.00  1.56       NaN
#  ...              ...   ...     ...  ...       ...   ...   ...       ...
#  1902           False     0   False  ... -2.157198  0.00  2.20  1.978571
#  1903           False     0   False  ... -2.256051  4.20  0.00  2.021429
#  1904           False     0   False  ... -2.234371  0.00  1.25  2.021429
#  1905            True     0   False  ... -1.833244  3.45  0.00  2.267857
#  1906            True   100    True  ... -1.364299  1.05  0.00  2.239286
#
#        AVG_Loss        RS        RSI     RSI_ta         FI_1         FI_13
#  0          NaN       NaN        NaN        NaN          NaN           NaN
#  1          NaN       NaN        NaN        NaN   2897278.72           NaN
#  2          NaN       NaN        NaN        NaN    547000.88           NaN
#  3          NaN       NaN        NaN        NaN -22825421.42           NaN
#  4          NaN       NaN        NaN        NaN  -4858766.64           NaN
#  ...        ...       ...        ...        ...          ...           ...
#  1902  3.385714  0.584388  36.884154  31.274111 -18600491.80 -1.345643e+08
#  1903  3.385714  0.597046  37.384412  35.267092  46889808.00 -1.086423e+08
#  1904  3.450000  0.585921  36.945170  34.622361  -6373923.75 -9.403253e+07
#  1905  3.075000  0.737515  42.446524  37.991760  20473704.15 -7.767450e+07
#  1906  3.075000  0.728223  42.137097  39.021797   4689058.50 -6.590827e+07
#
#  [1907 rows x 27 columns],
#  'WIPRO_minute':              datec          date   close    high     low    open  volume  \
#  0       2015-02-02  16468.156250  231.08  231.19  230.30  230.30   48974
#  1       2015-02-02  16468.156944  230.86  231.20  230.83  231.08   66320
#  2       2015-02-02  16468.157639  230.40  230.85  230.19  230.85   39996
#  3       2015-02-02  16468.158333  230.60  230.83  230.40  230.40   41876
#  4       2015-02-02  16468.159028  230.66  230.79  230.53  230.74   26006
#  ...            ...           ...     ...     ...     ...     ...     ...
#  671079  2022-10-24  19289.569444  384.60  384.65  384.45  384.45   20172
#  671080  2022-10-24  19289.570139  384.40  384.60  384.30  384.60   14347
#  671081  2022-10-24  19289.570833  384.40  384.55  384.30  384.40   32945
#  671082  2022-10-24  19289.571528  384.50  384.50  384.35  384.40   14599
#  671083  2022-10-24  19289.572222  384.50  384.50  384.15  384.50   24124
#
#          VolumePositive  Doji  IsDoji  ...  macdhist  Gain  Loss  AVG_Gain  \
#  0                 True     0   False  ...       NaN   NaN   NaN       NaN
#  1                False     0   False  ...       NaN  0.00  0.22       NaN
#  2                False     0   False  ...       NaN  0.00  0.46       NaN
#  3                 True     0   False  ...       NaN  0.20  0.00       NaN
#  4                False     0   False  ...       NaN  0.06  0.00       NaN
#  ...                ...   ...     ...  ...       ...   ...   ...       ...
#  671079            True     0   False  ... -0.029509  0.15  0.00  0.067857
#  671080           False     0   False  ... -0.029256  0.00  0.20  0.057143
#  671081           False   100    True  ... -0.026890  0.00  0.00  0.057143
#  671082            True     0   False  ... -0.016881  0.10  0.00  0.064286
#  671083           False   100    True  ... -0.008949  0.00  0.00  0.064286
#
#          AVG_Loss        RS        RSI     RSI_ta      FI_1        FI_13
#  0            NaN       NaN        NaN        NaN       NaN          NaN
#  1            NaN       NaN        NaN        NaN -14590.40          NaN
#  2            NaN       NaN        NaN        NaN -18398.16          NaN
#  3            NaN       NaN        NaN        NaN   8375.20          NaN
#  4            NaN       NaN        NaN        NaN   1560.36          NaN
#  ...          ...       ...        ...        ...       ...          ...
#  671079  0.078571  0.863636  46.341463  47.755940   3025.80  -844.493118
#  671080  0.092857  0.615385  38.095238  42.646009  -2869.40 -1133.765530
#  671081  0.092857  0.615385  38.095238  42.646009      0.00  -971.799025
#  671082  0.092857  0.692308  40.909091  45.996794   1459.90  -624.413450
#  671083  0.078571  0.818182  45.000000  45.996794      0.00  -535.211529
#
#  [671084 rows x 27 columns],
#  'YESBANK_60minute':             datec          date   close    high     low    open    volume  \
#  0      2015-02-02  16468.156250  168.18  171.21  168.12  171.21   5494810
#  1      2015-02-02  16468.197917  166.52  168.54  166.47  168.18   5590195
#  2      2015-02-02  16468.239583  165.65  166.64  164.30  166.52   6485280
#  3      2015-02-02  16468.281250  163.96  165.65  163.81  165.60   4449180
#  4      2015-02-02  16468.322917  167.60  167.98  163.86  163.94  11218235
#  ...           ...           ...     ...     ...     ...     ...       ...
#  12769  2022-10-21  19286.239583   16.15   16.20   16.10   16.20   5745089
#  12770  2022-10-21  19286.281250   16.20   16.25   16.15   16.20   4515701
#  12771  2022-10-21  19286.322917   15.95   16.20   15.95   16.15  10724216
#  12772  2022-10-21  19286.364583   16.00   16.05   15.90   15.95   9253677
#  12773  2022-10-21  19286.406250   16.15   16.15   16.00   16.00   8124962
#
#         VolumePositive  Doji  IsDoji  ...  macdhist  Gain  Loss  AVG_Gain  \
#  0               False     0   False  ...       NaN   NaN   NaN       NaN
#  1               False     0   False  ...       NaN  0.00  1.66       NaN
#  2               False     0   False  ...       NaN  0.00  0.87       NaN
#  3               False     0   False  ...       NaN  0.00  1.69       NaN
#  4                True     0   False  ...       NaN  3.64  0.00       NaN
#  ...               ...   ...     ...  ...       ...   ...   ...       ...
#  12769           False     0   False  ...  0.041236  0.00  0.05  0.032143
#  12770           False   100    True  ...  0.043667  0.05  0.00  0.035714
#  12771           False     0   False  ...  0.026758  0.00  0.25  0.035714
#  12772            True     0   False  ...  0.017698  0.05  0.00  0.039286
#  12773            True     0   False  ...  0.020374  0.15  0.00  0.050000
#
#         AVG_Loss        RS        RSI     RSI_ta         FI_1          FI_13
#  0           NaN       NaN        NaN        NaN          NaN            NaN
#  1           NaN       NaN        NaN        NaN  -9279723.70            NaN
#  2           NaN       NaN        NaN        NaN  -5642193.60            NaN
#  3           NaN       NaN        NaN        NaN  -7519114.20            NaN
#  4           NaN       NaN        NaN        NaN  40834375.40            NaN
#  ...         ...       ...        ...        ...          ...            ...
#  12769  0.021429  1.500000  60.000000  64.583825   -287254.45  505169.979131
#  12770  0.021429  1.666667  62.500000  66.817508    225785.05  465257.846398
#  12771  0.035714  1.000000  50.000000  49.878499  -2681054.00   15784.725484
#  12772  0.032143  1.222222  55.000000  52.473561    462683.85   79627.457558
#  12773  0.032143  1.555556  60.869565  59.284262   1218744.30  242358.435050
#
#  [12774 rows x 27 columns],
#  'YESBANK_day':            datec          date   close    high     low    open    volume  \
#  0     2015-01-01  16435.770833  154.51  154.93  153.21  153.80   3675025
#  1     2015-01-02  16436.770833  158.44  159.16  154.20  154.60  10627395
#  2     2015-01-05  16439.770833  158.78  160.98  157.96  159.30  14164070
#  3     2015-01-06  16440.770833  154.33  157.76  153.67  157.71  12749005
#  4     2015-01-07  16441.770833  151.47  155.20  150.85  154.00  15567125
#  ...          ...           ...     ...     ...     ...     ...       ...
#  1902  2022-10-17  19281.770833   15.75   16.05   15.65   15.70  83954100
#  1903  2022-10-18  19282.770833   15.85   15.95   15.70   15.85  45399847
#  1904  2022-10-19  19283.770833   15.90   16.05   15.80   15.85  44781578
#  1905  2022-10-20  19284.770833   15.95   16.00   15.75   15.85  29372277
#  1906  2022-10-21  19285.770833   16.05   16.35   15.90   16.15  62881273
#
#        VolumePositive  Doji  IsDoji  ...  macdhist  Gain  Loss  AVG_Gain  \
#  0               True     0   False  ...       NaN   NaN   NaN       NaN
#  1               True     0   False  ...       NaN  3.93  0.00       NaN
#  2              False     0   False  ...       NaN  0.34  0.00       NaN
#  3              False     0   False  ...       NaN  0.00  4.45       NaN
#  4              False     0   False  ...       NaN  0.00  2.86       NaN
#  ...              ...   ...     ...  ...       ...   ...   ...       ...
#  1902            True     0   False  ... -0.042051  0.00  0.05  0.114286
#  1903           False   100    True  ... -0.037165  0.10  0.00  0.103571
#  1904            True     0   False  ... -0.028210  0.05  0.00  0.107143
#  1905            True     0   False  ... -0.017110  0.05  0.00  0.107143
#  1906           False     0   False  ... -0.002017  0.10  0.00  0.103571
#
#        AVG_Loss        RS        RSI     RSI_ta         FI_1         FI_13
#  0          NaN       NaN        NaN        NaN          NaN           NaN
#  1          NaN       NaN        NaN        NaN  41765662.35           NaN
#  2          NaN       NaN        NaN        NaN   4815783.80           NaN
#  3          NaN       NaN        NaN        NaN -56733072.25           NaN
#  4          NaN       NaN        NaN        NaN -44521977.50           NaN
#  ...        ...       ...        ...        ...          ...           ...
#  1902  0.096429  1.185185  54.237288  43.787267  -4197705.00  8.364418e+05
#  1903  0.096429  1.074074  51.785714  45.578860   4539984.70  1.365519e+06
#  1904  0.075000  1.428571  58.823529  46.497060   2239078.90  1.490314e+06
#  1905  0.075000  1.428571  58.823529  47.451857   1468613.85  1.487214e+06
#  1906  0.075000  1.380952  58.000000  49.396885   6288127.30  2.173058e+06
#
#  [1907 rows x 27 columns],
#  'YESBANK_minute':              datec          date   close    high     low    open   volume  \
#  0       2015-02-02  16468.156250  169.60  171.21  169.40  171.21   291430
#  1       2015-02-02  16468.156944  169.23  169.73  169.13  169.46   263670
#  2       2015-02-02  16468.157639  169.83  169.91  169.14  169.22   222355
#  3       2015-02-02  16468.158333  169.93  170.18  169.88  169.91   127115
#  4       2015-02-02  16468.159028  170.15  170.20  169.93  169.97   113085
#  ...            ...           ...     ...     ...     ...     ...      ...
#  671071  2022-10-24  19289.569444   15.75   15.75   15.70   15.75   460825
#  671072  2022-10-24  19289.570139   15.75   15.75   15.70   15.75   487380
#  671073  2022-10-24  19289.570833   15.75   15.80   15.70   15.75  1686543
#  671074  2022-10-24  19289.571528   15.75   15.75   15.70   15.75   540365
#  671075  2022-10-24  19289.572222   15.70   15.75   15.70   15.70   570185
#
#          VolumePositive  Doji  IsDoji  ...  macdhist  Gain  Loss  AVG_Gain  \
#  0                False     0   False  ...       NaN   NaN   NaN       NaN
#  1                False     0   False  ...       NaN  0.00  0.37       NaN
#  2                 True     0   False  ...       NaN  0.60  0.00       NaN
#  3                 True     0   False  ...       NaN  0.10  0.00       NaN
#  4                 True     0   False  ...       NaN  0.22  0.00       NaN
#  ...                ...   ...     ...  ...       ...   ...   ...       ...
#  671071           False   100    True  ...  0.001852  0.00  0.00  0.007143
#  671072           False   100    True  ...  0.002351  0.00  0.00  0.007143
#  671073           False   100    True  ...  0.002693  0.00  0.00  0.007143
#  671074           False   100    True  ...  0.002912  0.00  0.00  0.007143
#  671075           False   100    True  ... -0.000156  0.00  0.05  0.007143
#
#          AVG_Loss        RS   RSI     RSI_ta       FI_1        FI_13
#  0            NaN       NaN   NaN        NaN        NaN          NaN
#  1            NaN       NaN   NaN        NaN  -97557.90          NaN
#  2            NaN       NaN   NaN        NaN  133413.00          NaN
#  3            NaN       NaN   NaN        NaN   12711.50          NaN
#  4            NaN       NaN   NaN        NaN   24878.70          NaN
#  ...          ...       ...   ...        ...        ...          ...
#  671071  0.010714  0.666667  40.0  46.184204       0.00 -2813.681419
#  671072  0.010714  0.666667  40.0  46.184204       0.00 -2411.726931
#  671073  0.010714  0.666667  40.0  46.184204       0.00 -2067.194512
#  671074  0.007143  1.000000  50.0  46.184204       0.00 -1771.881010
#  671075  0.010714  0.666667  40.0  36.223964  -28509.25 -5591.505152
#
#  [671076 rows x 27 columns]}

# %%
data_day = {}
data_hour = {}
data_minute = {}

for key, value in final_data.items():
    if key.endswith('_day'):
        data_day[key] = value
    elif key.endswith('_60minute'):
        data_hour[key] = value
    elif key.endswith('_minute'):
        data_minute[key] = value

# %%
df = HDFC_minute

# %% [markdown]
# ## Narrow - day FIB : 3:1

# %%
class Trade_short:
    def __init__(self, *args, **kwargs):
        self.entry_flag = False
        self.entry_price = 0
        self.df = None
        self.profit_window = kwargs.get('profit_window', 3)
        self.loss_window = kwargs.get('loss_window', 1)

    def process_data(self, df):
        self.df = df.copy()  # Make a copy of the input DataFrame

        for i in range(len(self.df)):
            if i < 50:  # Adjust the skip condition to accommodate SMA_50
                self.df.loc[i, 'trade'] = 'n'
                continue
            elif self.df.loc[i, 'SMA_20'] > self.df.loc[i, 'SMA_50'] and self.df.loc[i-1, 'SMA_20'] < self.df.loc[i, 'SMA_50'] and not self.entry_flag:
                self.entry_price = self.df.loc[i, 'close']
                self.entry_flag = True
                self.df.loc[i, 'trade'] = 'E'  # Entry point marked with 'E'
            elif self.entry_flag:
                trade_value = ((self.df.loc[i, 'close'] - self.entry_price) / self.entry_price) * 100
                if trade_value >= self.profit_window:
                    self.df.loc[i, 'trade'] = 'P'
                    self.entry_flag = False
                elif trade_value <= -self.loss_window:
                    self.df.loc[i, 'trade'] = 'L'
                    self.entry_flag = False
                else:
                    self.df.loc[i, 'trade'] = 'C'
            else:
                self.df.loc[i, 'trade'] = 'C'

        return self.df

    def result_counts(self):
        entry_count = self.df[self.df['trade'] == 'E'].shape[0]
        profit_count = self.df[self.df['trade'] == 'P'].shape[0]
        loss_count = self.df[self.df['trade'] == 'L'].shape[0]

        counts_df = pd.DataFrame({
            'Category': ['Entry (E)', 'Profit (P)', 'Loss (L)'],
            'Count': [entry_count, profit_count, loss_count]
        })

        return counts_df

# %%
# Example usage
trade_instance_custom = Trade_short(profit_window=3, loss_window=1)

# Process data using the process_data method with custom hyperparameters
result_df_custom = trade_instance_custom.process_data(df)

# Get result counts using the result_counts method
counts_result_df_custom = trade_instance_custom.result_counts()

print(counts_result_df_custom)
# Out:
#      Category  Count
# 0   Entry (E)     19
# 1  Profit (P)     12
# 2    Loss (L)      7

# %% [markdown]
# ## Broad Day FIB : 3:1

# %%
class Trade_long:
    def __init__(self, *args, **kwargs):
        self.entry_flag = False
        self.entry_price = 0
        self.df = None
        self.profit_window = kwargs.get('profit_window', 3)
        self.loss_window = kwargs.get('loss_window', 1)

    def process_data(self, df):
        self.df = df.copy()  # Make a copy of the input DataFrame

        for i in range(len(self.df)):
            if i < 200:  # Adjust the skip condition to accommodate SMA_200
                self.df.loc[i, 'trade'] = 'n'
                continue
            elif (
                self.df.loc[i, 'SMA_50'] > self.df.loc[i, 'SMA_200']
                and self.df.loc[i-1, 'SMA_50'] < self.df.loc[i, 'SMA_200']
                and not self.entry_flag
            ):
                self.entry_price = self.df.loc[i, 'close']
                self.entry_flag = True
                self.df.loc[i, 'trade'] = 'E'  # Entry point marked with 'E'
            elif self.entry_flag:
                trade_value = ((self.df.loc[i, 'close'] - self.entry_price) / self.entry_price) * 100
                if trade_value >= self.profit_window:
                    self.df.loc[i, 'trade'] = 'P'
                    self.entry_flag = False
                elif trade_value <= -self.loss_window:
                    self.df.loc[i, 'trade'] = 'L'
                    self.entry_flag = False
                else:
                    self.df.loc[i, 'trade'] = 'C'
            else:
                self.df.loc[i, 'trade'] = 'C'

        return self.df

    def result_counts(self):
        entry_count = self.df[self.df['trade'] == 'E'].shape[0]
        profit_count = self.df[self.df['trade'] == 'P'].shape[0]
        loss_count = self.df[self.df['trade'] == 'L'].shape[0]

        counts_df = pd.DataFrame({
            'Category': ['Entry (E)', 'Profit (P)', 'Loss (L)'],
            'Count': [entry_count, profit_count, loss_count]
        })

        return counts_df

# %%
# Example usage
trade_instance_custom = Trade_long(profit_window=3, loss_window=1)

# Process data using the process_data method with custom hyperparameters
result_df_custom = trade_instance_custom.process_data(df)

# Get result counts using the result_counts method
counts_result_df_custom = trade_instance_custom.result_counts()

print(counts_result_df_custom)
# Out:
#      Category  Count
# 0   Entry (E)      4
# 1  Profit (P)      1
# 2    Loss (L)      3

# %% [markdown]
# ## Long Day FIB : 3:1

# %%
# Example usage
trade_instance_custom = Trade_short(profit_window=15, loss_window=5)

# Process data using the process_data method with custom hyperparameters
result_df_custom = trade_instance_custom.process_data(df)

# Get result counts using the result_counts method
counts_result_df_custom = trade_instance_custom.result_counts()

print(counts_result_df_custom)
# Out:
#      Category  Count
# 0   Entry (E)     13
# 1  Profit (P)      5
# 2    Loss (L)      7

# %% [markdown]
# ## Broad FIB : 15:5

# %%
# Example usage
trade_instance_custom = Trade_long(profit_window=15, loss_window=5)

# Process data using the process_data method with custom hyperparameters
result_df_custom = trade_instance_custom.process_data(df)

# Get result counts using the result_counts method
counts_result_df_custom = trade_instance_custom.result_counts()

print(counts_result_df_custom)
# Out:
#      Category  Count
# 0   Entry (E)      4
# 1  Profit (P)      2
# 2    Loss (L)      2

# %% [markdown]
# ## Hourly 3:1

# %%
dfs = HDFC_minute

# %%
# Example usage
trade_instance_custom = Trade_short(profit_window=3, loss_window=1)

# Process data using the process_data method with custom hyperparameters
result_df_custom = trade_instance_custom.process_data(dfs)

# Get result counts using the result_counts method
counts_result_df_custom = trade_instance_custom.result_counts()

print(counts_result_df_custom)
# Out:
#      Category  Count
# 0   Entry (E)    126
# 1  Profit (P)     41
# 2    Loss (L)     85

# %% [markdown]
# ## Hourly Broad 3:1

# %%
# Example usage
trade_instance_custom = Trade_long(profit_window=3, loss_window=1)

# Process data using the process_data method with custom hyperparameters
result_df_custom = trade_instance_custom.process_data(dfs)

# Get result counts using the result_counts method
counts_result_df_custom = trade_instance_custom.result_counts()

print(counts_result_df_custom)
# Out:
#      Category  Count
# 0   Entry (E)     34
# 1  Profit (P)     11
# 2    Loss (L)     23

# %% [markdown]
# ## Hourly Narrow 15:5

# %%
# Example usage
trade_instance_custom = Trade_short(profit_window=15, loss_window=5)

# Process data using the process_data method with custom hyperparameters
result_df_custom = trade_instance_custom.process_data(dfs)

# Get result counts using the result_counts method
counts_result_df_custom = trade_instance_custom.result_counts()

print(counts_result_df_custom)
# Out:
#      Category  Count
# 0   Entry (E)     45
# 1  Profit (P)     13
# 2    Loss (L)     31

# %% [markdown]
# ## Hourly Broad 15:5

# %%
# Example usage
trade_instance_custom = Trade_long(profit_window=15, loss_window=5)

# Process data using the process_data method with custom hyperparameters
result_df_custom = trade_instance_custom.process_data(dfs)

# Get result counts using the result_counts method
counts_result_df_custom = trade_instance_custom.result_counts()

print(counts_result_df_custom)
# Out:
#      Category  Count
# 0   Entry (E)     19
# 1  Profit (P)      7
# 2    Loss (L)     11

# %%
#######

# %%
class Trade:
    def __init__(self, *args, **kwargs):
        self.entry_flag = False
        self.entry_price = 0
        self.df = None
        self.profit_window = kwargs.get('profit_window', 3)
        self.loss_window = kwargs.get('loss_window', 1)

    def process_data(self, df):
        self.df = df.copy()  # Make a copy of the input DataFrame

        for i in range(len(self.df)):
            if i < 50:  # Adjust the skip condition to accommodate SMA_50
                self.df.loc[i, 'trade'] = 'n'
                continue
            elif (self.df.loc[i, 'SMA_20'] > self.df.loc[i, 'SMA_50'] and self.df.loc[i-1, 'SMA_20'] < self.df.loc[i, 'SMA_50'] or
                  self.df.loc[i, 'SMA_50'] > self.df.loc[i, 'SMA_200'] and self.df.loc[i-1, 'SMA_50'] < self.df.loc[i, 'SMA_200']) and not self.entry_flag:
                self.entry_price = self.df.loc[i, 'close']
                self.entry_flag = True
                self.df.loc[i, 'trade'] = 'E'  # Entry point marked with 'E'
            elif self.entry_flag:
                trade_value = ((self.df.loc[i, 'close'] - self.entry_price) / self.entry_price) * 100
                if trade_value >= self.profit_window:
                    self.df.loc[i, 'trade'] = 'P'
                    self.entry_flag = False
                elif trade_value <= -self.loss_window:
                    self.df.loc[i, 'trade'] = 'L'
                    self.entry_flag = False
                else:
                    self.df.loc[i, 'trade'] = 'C'
            else:
                self.df.loc[i, 'trade'] = 'C'

        return self.df

    def result_counts(self):
        entry_count = self.df[self.df['trade'] == 'E'].shape[0]
        profit_count = self.df[self.df['trade'] == 'P'].shape[0]
        loss_count = self.df[self.df['trade'] == 'L'].shape[0]
        
        total_trades = entry_count + profit_count + loss_count
        
        # Calculate percentage of profitable trades
        if total_trades > 0:
            percent_profitable = round((profit_count / total_trades) * 100, 2)
        else:
            percent_profitable = 0
        
        counts_array = [
            entry_count, profit_count, loss_count, percent_profitable
        ]
    
        return counts_array

# %%
# Create an instance of the Trade class
trade_instance = Trade()

# Apply the process_data method to generate trade signals
df_with_trades = trade_instance.process_data(df)

# Get the result counts
result_counts = trade_instance.result_counts()
print(result_counts)
# Out:
# [22, 12, 10, 27.27]

# %%
# Assuming you have a list called profit_windows
profit_windows = [(1, 0.33), (3, 1), (15, 5), (30, 10)]

# Initialize an empty list to store DataFrames
results_df_list = []

for profit_window, loss_window in profit_windows:
    # Instantiate Trade class with the current profit_window and loss_window values
    trade_instance = Trade(profit_window=profit_window, loss_window=loss_window)
    
    # Process data using the Trade instance
    processed_data = trade_instance.process_data(df)
    
    # Get result counts using the result_counts method
    result_counts_array = trade_instance.result_counts()
    
    # Create a DataFrame from the current result
    current_result_df = pd.DataFrame({
        'Profit_Loss_Windows': [(profit_window, loss_window)],
        'Result_Counts(E, P, L, P%)': [result_counts_array]
    })

    # Append the current DataFrame to the list
    results_df_list.append(current_result_df)

# Use pd.concat to concatenate the list of DataFrames
results_df = pd.concat(results_df_list, ignore_index=True)

# Display the final results DataFrame
results_df
# Out:
#   Profit_Loss_Windows Result_Counts(E, P, L, P%)
# 0           (1, 0.33)  [3672, 1069, 2602, 14.56]
# 1              (3, 1)    [1071, 322, 748, 15.04]
# 2             (15, 5)        [70, 22, 47, 15.83]
# 3            (10, 30)         [15, 13, 1, 44.83]

# %%
for profit_window, loss_window in profit_windows:
    # Instantiate Trade class with the current profit_window and loss_window values
    trade_instance = Trade(profit_window=profit_window, loss_window=loss_window)
    
    # Process data using the Trade instance
    processed_data = trade_instance.process_data(df)
    
    # Get result counts using the result_counts method
    result_counts_array = trade_instance.result_counts()
    
    # Create a DataFrame from the current result
    current_result_df = pd.DataFrame({
        'Profit_Loss_Windows': [(profit_window, loss_window)],
        'Result_Counts(E, P, L, P%)': [result_counts_array]
    })

    # Add a new column for each DataFrame in the data_day dictionary
    for key, df_day in data_day.items():
        column_name = key.split('_')[0]  # Get the part before the first underscore
        current_result_df[column_name] = len(df_day)

    # Append the current DataFrame to the list
    results_df_list.append(current_result_df)

# Use pd.concat to concatenate the list of DataFrames
results_df = pd.concat(results_df_list, ignore_index=True)

# Display the final results DataFrame
results_df
