# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import talib

import warnings
warnings.filterwarnings("ignore")

# yahoo finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
# input
symbol = 'HDB'
start = '2020-01-01'
end = '2021-10-11'

# Read data 
df = yf.download(symbol,start,end)

# View Columns
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2019-12-31  62.820000  63.400002  62.730000  63.369999  61.784687   514300
# 2020-01-02  63.860001  64.190002  63.299999  63.700001  62.106434  1115700
# 2020-01-03  62.930000  63.090000  61.959999  62.009998  60.458710  1491700
# 2020-01-06  61.000000  61.310001  60.369999  60.910000  59.386230  2323000
# 2020-01-07  61.279999  61.470001  60.689999  60.689999  59.171734  1228400

# %%
from matplotlib import dates as mdates
import datetime as dt

dfc = df.copy()
dfc['VolumePositive'] = dfc['Open'] < dfc['Adj Close']
#dfc = dfc.dropna()
dfc = dfc.reset_index()
dfc['Date'] = pd.to_datetime(dfc['Date'])
dfc['Date'] = dfc['Date'].apply(mdates.date2num)
dfc.head()
# Out:
#       Date       Open       High        Low      Close  Adj Close   Volume  \
# 0  18261.0  62.820000  63.400002  62.730000  63.369999  61.784687   514300
# 1  18263.0  63.860001  64.190002  63.299999  63.700001  62.106434  1115700
# 2  18264.0  62.930000  63.090000  61.959999  62.009998  60.458710  1491700
# 3  18267.0  61.000000  61.310001  60.369999  60.910000  59.386230  2323000
# 4  18268.0  61.279999  61.470001  60.689999  60.689999  59.171734  1228400
#
#    Doji  VolumePositive
# 0     0           False
# 1     0           False
# 2     0           False
# 3     0           False
# 4     0           False

# %%
from mplfinance.original_flavor import candlestick_ohlc

fig = plt.figure(figsize=(14,10))
ax = plt.subplot(2, 1, 1)
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax.grid(True, which='both')
ax.minorticks_on()
axv = ax.twinx()
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
doji = talib.CDLDOJI(df['Open'], df['High'], df['Low'], df['Close'])

doji = doji[doji != 0]

# %%
df['Doji'] = talib.CDLDOJI(df['Open'], df['High'], df['Low'], df['Close'])

# %%
df.loc[df['Doji'] !=0]
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2020-01-17  61.700001  61.860001  61.349998  61.740002  60.195465  1156100
# 2020-01-31  57.340000  57.610001  56.939999  57.279999  55.847038  2357000
# 2020-02-20  58.020000  58.459999  57.599998  57.970001  56.519779  1612600
# 2020-03-04  53.049999  53.279999  52.669998  52.980000  51.654613  3261200
# 2020-03-09  49.310001  49.990002  48.000000  49.189999  47.959427  3550100
# 2020-03-12  44.790001  45.549999  43.450001  44.750000  43.630501  3941500
# 2020-03-16  43.000000  45.430000  42.889999  43.139999  42.060780  3796000
# 2020-03-27  39.369999  40.660000  37.070000  39.310001  38.326591  5284400
# 2020-04-15  38.439999  39.150002  38.110001  38.590000  37.624603  1994300
# 2020-04-22  40.930000  41.049999  39.950001  40.779999  39.759811  2550400
# 2020-04-23  41.000000  41.840000  40.669998  40.880001  39.857315  2234200
# 2020-04-27  40.509998  40.740002  40.029999  40.590000  39.574570  2211700
# 2020-05-01  42.250000  42.320000  41.410000  42.099998  41.046795  1402300
# 2020-05-05  40.650002  41.660000  40.619999  40.759998  39.740318  1290000
# 2020-06-01  42.459999  43.209999  42.060001  42.509998  41.446533  2316300
# 2020-06-05  47.639999  47.650002  46.639999  47.610001  46.418953  3363600
# 2020-06-17  42.830002  43.000000  42.540001  42.720001  41.651283  1523100
# 2020-06-19  44.630001  45.080002  44.099998  44.689999  43.572002  2611700
# 2020-06-23  45.509998  46.230000  45.349998  45.430000  44.293491  2453300
# 2020-06-29  45.660000  45.849998  45.220001  45.619999  44.478737  2149200
# 2020-06-30  45.529999  45.630001  44.980000  45.459999  44.322739  1625000
# 2020-07-09  48.630001  48.860001  48.009998  48.549999  47.335434  1378500
# 2020-07-15  46.700001  47.410000  46.599998  46.730000  45.560966  1328300
# 2020-07-16  46.520000  46.779999  46.240002  46.459999  45.297718   808100
# 2020-07-23  50.090000  50.730000  49.919998  50.150002  48.895409  1174500
# 2020-07-27  48.459999  49.099998  48.360001  48.549999  47.335434  2870900
# 2020-07-31  46.799999  47.230000  46.169998  46.750000  45.580467  2879200
# 2020-08-03  45.709999  46.099998  45.400002  45.759998  44.615231  2728400
# 2020-08-05  46.450001  46.770000  46.090000  46.410000  45.248974  1379000
# 2020-08-07  46.480000  46.529999  45.910000  46.529999  45.365974  1407900
# 2020-08-25  50.009998  50.200001  49.520000  50.090000  48.836910   999700
# 2020-09-08  49.560001  50.169998  49.330002  49.470001  48.232422  1590500
# 2020-09-11  49.290001  49.400002  48.750000  49.330002  48.095924  1018500
# 2020-09-15  49.570000  49.820000  49.380001  49.490002  48.251923  1048700
# 2020-09-18  48.919998  49.299999  48.709999  48.990002  47.764431  1139000
# 2020-10-08  54.889999  55.299999  54.000000  54.849998  53.477829  1746900
# 2020-10-09  56.310001  56.680000  56.080002  56.220001  54.813557  1253900
# 2020-10-26  59.480000  59.650002  59.290001  59.450001  57.962753  1528100
# 2020-10-29  57.669998  57.820000  57.160000  57.599998  56.159035  1834600
# 2020-11-19  66.690002  66.849998  66.250000  66.620003  64.953392  1373500
# 2020-12-17  70.250000  70.949997  69.769997  70.349998  68.590073  1899400
# 2021-01-14  75.639999  75.900002  75.129997  75.669998  73.776985  1052700
# 2021-02-17  81.839996  81.870003  80.940002  81.809998  79.763374  1038200
# 2021-03-05  82.169998  82.470001  80.010002  82.279999  80.221619  1587900
# 2021-03-11  83.660004  84.000000  83.029999  83.750000  81.654846  1163900
# 2021-03-23  79.139999  80.000000  78.519997  79.169998  77.189423   951500
# 2021-04-14  70.389999  70.820000  69.940002  70.529999  68.765564  1733600
# 2021-04-16  71.910004  72.010002  71.360001  71.809998  70.013542  1407900
# 2021-04-23  69.419998  69.769997  69.169998  69.430000  67.693085   956100
# 2021-05-14  70.019997  70.089996  68.779999  70.080002  68.326828   918800
# 2021-06-10  77.239998  77.449997  76.500000  77.239998  75.307709   848400
# 2021-06-11  77.419998  77.589996  76.930000  77.459999  75.522202   679300
# 2021-06-22  74.879997  75.269997  74.480003  74.769997  72.899490   846700
# 2021-09-01  78.849998  79.010002  78.320000  78.849998  77.148323  2447400
# 2021-09-27  74.410004  74.680000  74.250000  74.440002  72.833504  2736700
#
#             Doji
# Date
# 2020-01-17   100
# 2020-01-31   100
# 2020-02-20   100
# 2020-03-04   100
# 2020-03-09   100
# 2020-03-12   100
# 2020-03-16   100
# 2020-03-27   100
# 2020-04-15   100
# 2020-04-22   100
# 2020-04-23   100
# 2020-04-27   100
# 2020-05-01   100
# 2020-05-05   100
# 2020-06-01   100
# 2020-06-05   100
# 2020-06-17   100
# 2020-06-19   100
# 2020-06-23   100
# 2020-06-29   100
# 2020-06-30   100
# 2020-07-09   100
# 2020-07-15   100
# 2020-07-16   100
# 2020-07-23   100
# 2020-07-27   100
# 2020-07-31   100
# 2020-08-03   100
# 2020-08-05   100
# 2020-08-07   100
# 2020-08-25   100
# 2020-09-08   100
# 2020-09-11   100
# 2020-09-15   100
# 2020-09-18   100
# 2020-10-08   100
# 2020-10-09   100
# 2020-10-26   100
# 2020-10-29   100
# 2020-11-19   100
# 2020-12-17   100
# 2021-01-14   100
# 2021-02-17   100
# 2021-03-05   100
# 2021-03-11   100
# 2021-03-23   100
# 2021-04-14   100
# 2021-04-16   100
# 2021-04-23   100
# 2021-05-14   100
# 2021-06-10   100
# 2021-06-11   100
# 2021-06-22   100
# 2021-09-01   100
# 2021-09-27   100

# %%
df['Adj Close'].loc[df['Doji'] !=0]
# Out:
# Date
# 2020-01-17    60.195465
# 2020-01-31    55.847038
# 2020-02-20    56.519779
# 2020-03-04    51.654613
# 2020-03-09    47.959427
# 2020-03-12    43.630501
# 2020-03-16    42.060780
# 2020-03-27    38.326591
# 2020-04-15    37.624603
# 2020-04-22    39.759811
# 2020-04-23    39.857315
# 2020-04-27    39.574570
# 2020-05-01    41.046795
# 2020-05-05    39.740318
# 2020-06-01    41.446533
# 2020-06-05    46.418953
# 2020-06-17    41.651283
# 2020-06-19    43.572002
# 2020-06-23    44.293491
# 2020-06-29    44.478737
# 2020-06-30    44.322739
# 2020-07-09    47.335434
# 2020-07-15    45.560966
# 2020-07-16    45.297718
# 2020-07-23    48.895409
# 2020-07-27    47.335434
# 2020-07-31    45.580467
# 2020-08-03    44.615231
# 2020-08-05    45.248974
# 2020-08-07    45.365974
# 2020-08-25    48.836910
# 2020-09-08    48.232422
# 2020-09-11    48.095924
# 2020-09-15    48.251923
# 2020-09-18    47.764431
# 2020-10-08    53.477829
# 2020-10-09    54.813557
# 2020-10-26    57.962753
# 2020-10-29    56.159035
# 2020-11-19    64.953392
# 2020-12-17    68.590073
# 2021-01-14    73.776985
# 2021-02-17    79.763374
# 2021-03-05    80.221619
# 2021-03-11    81.654846
# 2021-03-23    77.189423
# 2021-04-14    68.765564
# 2021-04-16    70.013542
# 2021-04-23    67.693085
# 2021-05-14    68.326828
# 2021-06-10    75.307709
# 2021-06-11    75.522202
# 2021-06-22    72.899490
# 2021-09-01    77.148323
# 2021-09-27    72.833504
# Name: Adj Close, dtype: float64

# %%
df['Adj Close'].loc[df['Doji'] !=0].index
# Out:
# DatetimeIndex(['2020-01-17', '2020-01-31', '2020-02-20', '2020-03-04',
#                '2020-03-09', '2020-03-12', '2020-03-16', '2020-03-27',
#                '2020-04-15', '2020-04-22', '2020-04-23', '2020-04-27',
#                '2020-05-01', '2020-05-05', '2020-06-01', '2020-06-05',
#                '2020-06-17', '2020-06-19', '2020-06-23', '2020-06-29',
#                '2020-06-30', '2020-07-09', '2020-07-15', '2020-07-16',
#                '2020-07-23', '2020-07-27', '2020-07-31', '2020-08-03',
#                '2020-08-05', '2020-08-07', '2020-08-25', '2020-09-08',
#                '2020-09-11', '2020-09-15', '2020-09-18', '2020-10-08',
#                '2020-10-09', '2020-10-26', '2020-10-29', '2020-11-19',
#                '2020-12-17', '2021-01-14', '2021-02-17', '2021-03-05',
#                '2021-03-11', '2021-03-23', '2021-04-14', '2021-04-16',
#                '2021-04-23', '2021-05-14', '2021-06-10', '2021-06-11',
#                '2021-06-22', '2021-09-01', '2021-09-27'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
doji
# Out:
# Date
# 2020-01-17    100
# 2020-01-31    100
# 2020-02-20    100
# 2020-03-04    100
# 2020-03-09    100
# 2020-03-12    100
# 2020-03-16    100
# 2020-03-27    100
# 2020-04-15    100
# 2020-04-22    100
# 2020-04-23    100
# 2020-04-27    100
# 2020-05-01    100
# 2020-05-05    100
# 2020-06-01    100
# 2020-06-05    100
# 2020-06-17    100
# 2020-06-19    100
# 2020-06-23    100
# 2020-06-29    100
# 2020-06-30    100
# 2020-07-09    100
# 2020-07-15    100
# 2020-07-16    100
# 2020-07-23    100
# 2020-07-27    100
# 2020-07-31    100
# 2020-08-03    100
# 2020-08-05    100
# 2020-08-07    100
# 2020-08-25    100
# 2020-09-08    100
# 2020-09-11    100
# 2020-09-15    100
# 2020-09-18    100
# 2020-10-08    100
# 2020-10-09    100
# 2020-10-26    100
# 2020-10-29    100
# 2020-11-19    100
# 2020-12-17    100
# 2021-01-14    100
# 2021-02-17    100
# 2021-03-05    100
# 2021-03-11    100
# 2021-03-23    100
# 2021-04-14    100
# 2021-04-16    100
# 2021-04-23    100
# 2021-05-14    100
# 2021-06-10    100
# 2021-06-11    100
# 2021-06-22    100
# 2021-09-01    100
# 2021-09-27    100
# dtype: int32

# %%
doji.index
# Out:
# DatetimeIndex(['2020-01-17', '2020-01-31', '2020-02-20', '2020-03-04',
#                '2020-03-09', '2020-03-12', '2020-03-16', '2020-03-27',
#                '2020-04-15', '2020-04-22', '2020-04-23', '2020-04-27',
#                '2020-05-01', '2020-05-05', '2020-06-01', '2020-06-05',
#                '2020-06-17', '2020-06-19', '2020-06-23', '2020-06-29',
#                '2020-06-30', '2020-07-09', '2020-07-15', '2020-07-16',
#                '2020-07-23', '2020-07-27', '2020-07-31', '2020-08-03',
#                '2020-08-05', '2020-08-07', '2020-08-25', '2020-09-08',
#                '2020-09-11', '2020-09-15', '2020-09-18', '2020-10-08',
#                '2020-10-09', '2020-10-26', '2020-10-29', '2020-11-19',
#                '2020-12-17', '2021-01-14', '2021-02-17', '2021-03-05',
#                '2021-03-11', '2021-03-23', '2021-04-14', '2021-04-16',
#                '2021-04-23', '2021-05-14', '2021-06-10', '2021-06-11',
#                '2021-06-22', '2021-09-01', '2021-09-27'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
fig = plt.figure(figsize=(20,16))
ax = plt.subplot(2, 1, 1)
candlestick_ohlc(ax,dfc.values, width=0.5, colorup='g', colordown='r', alpha=1.0)
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax.grid(True, which='both')
ax.minorticks_on()
axv = ax.twinx()
ax.plot_date(df['Adj Close'].loc[df['Doji'] !=0].index, df['Adj Close'].loc[df['Doji'] !=0],
                'or', # marker style 'o', color 'g'
                fillstyle='none', # circle is not filled (with color)
                ms=10.0) 
colors = dfc.VolumePositive.map({True: 'g', False: 'r'})
axv.bar(dfc.Date, dfc['Volume'], color=colors, alpha=0.4)
axv.axes.yaxis.set_ticklabels([])
axv.set_ylim(0, 3*df.Volume.max())
ax.set_title('Stock '+ symbol +' Closing Price')
ax.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')
